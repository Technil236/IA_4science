# %% [markdown]
# #Data processing training

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.1.0+cu121'

# %% [markdown]
# #DATA can be anything

# %% [markdown]
# creating data from a linear regression to see if ze can built a model and figure out what are the parameters

# %%
#our known parameter
weight = 0.7
bias = 0.3

#creating data
start = 0
end = 1
step = 0.02
X= torch.arange (start, end,step).unsqueeze(dim=1)
y= weight*X + bias

X[:10] , y[:10] ,X.shape,y.shape
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]),
#  torch.Size([50, 1]),
#  torch.Size([50, 1]))

# %% [markdown]
# #splitting the data in trin and test sets

# %%
train_split = int(0.8*len(X))
X_train ,y_train = X[:train_split] , y[:train_split]
X_test ,y_test = X[train_split:] , y[train_split:]
len(X_train), len(y_train),len(X_test) ,len(y_test)
# Out:
# (40, 40, 10, 10)

# %%
def plot_prediction (train_data = X_train,
                     train_label = y_train,
                     test_data = X_test,
                     test_label = y_test,
                     predictions=None):
  plt.figure(figsize=(10,7))
  plt.scatter(train_data,train_label,c='b' ,s= 4 ,label="Training_data")
  plt.scatter(test_data,test_label,c='y' ,s= 4 ,label="Test_data")
  if predictions is not None:
    plt.scatter (test_data ,predictions , c='r' , s=4 , label  ='predictions')
    show.legend(prop={"size" : 14});

# %%
plot_prediction();

# %%
import matplotlib.pyplot as plt
import networkx as nx


G = nx.DiGraph()

#variabled
variables = ["Location", "Gender", "Prior Education", "Math Ability",
             "Coding Ability", "Socio-economic Reality",
             ]

G.add_nodes_from(variables)

# relationship between variable
relations = [("Location", "Socio-economic Reality"), ("Socio-economic Reality", "Prior Education"),
             ("Prior Education", "Math Ability"), ("Prior Education", "Coding Ability"),
             ("Gender", "Prior Education"),
            ]

G.add_edges_from(relations)

pos = nx.spring_layout(G)  # Positionnement des nœuds
nx.draw(G, pos, with_labels=True, font_weight='bold', node_size=700, node_color='skyblue', font_size=8, edge_color='gray', linewidths=0.5, arrowsize=10)

plt.title("Relations entre les Variables pour l'Admission en IA")
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
import seaborn as sns
import pandas as pd
import numpy as np

# Setting up the plotting
# %matplotlib inline
sns.set_style('whitegrid')

# Simulating data for the general population
np.random.seed(0)
population_size = 10000
general_population = pd.DataFrame({
    'Location': np.random.choice(['underdevelopped', 'in developpement'], size=population_size , p=[0.7, 0.3]),
    'Gender': np.random.choice(['Male', 'Female'], size=population_size, p=[0.8, 0.2]),
    'Prior Education': np.random.choice(['High School', 'College', 'University'], size=population_size, p=[0.7, 0.2, 0.1]),
    'Math Ability': np.random.choice(['Low', 'Medium', 'High'], size=population_size, p=[0.2,0.5, 0.3]),
    'Coding Ability': np.random.choice(['Low', 'Medium', 'High'], size=population_size,p=[0.15, 0.65, 0.2]),
    'Socio-economic Reality': np.random.choice(['Low', 'Medium', 'High'], size=population_size, p=[0.6, 0.3 , 0.1]),
})

general_population.head(20)
# Out:
#             Location  Gender Prior Education Math Ability Coding Ability  \
# 0    underdevelopped    Male     High School         High         Medium
# 1   in developpement    Male     High School       Medium         Medium
# 2    underdevelopped    Male      University          Low         Medium
# 3    underdevelopped    Male     High School         High            Low
# 4    underdevelopped    Male      University       Medium         Medium
# 5    underdevelopped  Female         College         High            Low
# 6    underdevelopped    Male      University         High         Medium
# 7   in developpement    Male         College       Medium         Medium
# 8   in developpement    Male     High School       Medium           High
# 9    underdevelopped  Female     High School       Medium         Medium
# 10  in developpement    Male         College       Medium         Medium
# 11   underdevelopped    Male     High School       Medium            Low
# ...

# %%
# Placeholder for causal graph creation (to be completed by students)
causal_graph = nx.DiGraph()

# Add nodes and edges to represent the causal relationships based on the data
causal_graph.add_edges_from([
    ('Location', 'Socio-economic Reality'),
    ('Socio-economic Reality', 'Prior Education'),
    ('Prior Education', 'Math Ability'),
    ('Prior Education', 'Coding Ability'),
    ('Gender', 'Prior Education'),
    ('Math Ability','selection'),
    ('coding ability', 'selection'),
])

# Plot the causal graph
nx.draw(causal_graph, with_labels=True)
plt.title("Causal Graph for Admission in AI")
plt.show()
